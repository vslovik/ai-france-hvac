# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

from etl.util import prepare_dataset_without_leakage
from ml_features.features import prepare_features
from ml_features.customer_features import create_customer_features
from ml_features.sequence_features  import create_sequence_features
from ml_features.brand_features import create_brand_features
from ml_features.model_features import create_model_features
from ml_features.market_features import create_market_features
from ml_features.equipment_features import create_equipment_features
from ml_features.solution_complexity_features import create_solution_complexity_features
from ml_features.timeline_features import create_timeline_features, create_advanced_timeline_features, create_timeline_interaction_features
from ml_features.role_features import create_commercial_role_features
from ml_features.process_features import create_process_features
from ml_features.correction_features import create_correction_features
from ml_features.catboost_interaction_features import create_catboost_interaction_features
from ml_features.efficiency_interation_features import create_efficiency_interaction_features
from ml_features.engagement_interation_features import create_engagement_interaction_features
from ml_features.advanced_features import create_advanced_interaction_features, create_conversion_pattern_features, create_precision_optimization_features, create_price_dominant_features
from ml_features.price_binning_features import create_price_binning_features
from ml_features.simulation_discovery import create_simulation_discovery_features
from ml_training.train_catboost import train_catboost
from ml_evaluation.dashboard import model_evaluation_report
from ml_evaluation.error_analysis import comprehensive_error_analysis, analyze_feature_contribution_to_errors, create_error_visualization


import warnings
warnings.filterwarnings('ignore')

# Load original clean quote data
df_quotes = pd.read_csv('cleaned_quote_data.csv')
df_quotes['dt_creation_devis'] = pd.to_datetime(df_quotes['dt_creation_devis'])
print(f"\n📊 Original quote data: {len(df_quotes):,} quotes from {df_quotes['numero_compte'].nunique():,} customers")


print("\n" + "="*80)
print("STRATEGY: CREATE FEATURES")
print("="*80)


# Create feature list
feature_funcs = [create_customer_features, create_sequence_features, create_brand_features, 
                 create_model_features, create_market_features,
                 create_equipment_features, create_solution_complexity_features,
                 create_timeline_features, create_advanced_timeline_features,
                 create_commercial_role_features, create_process_features
                 , create_correction_features
                ]


new_df = feature_funcs[0](df_quotes)
customer_df = new_df
for func in feature_funcs[1:]:
    new_df_ = func(df_quotes)

    new_df = pd.merge(new_df, new_df_, on='numero_compte', how='left', suffixes=('_dup', ''))
    new_df = new_df.drop(columns=[x for x in new_df.columns if '_dup' in x], errors='ignore')
    print(len(new_df))
    if func == create_sequence_features: sequence_df = new_df


# Now it's clear which column is which
y_new = new_df['converted']  # From sequence features
y_sequence = sequence_df['converted']  # From sequence features
y_customer = customer_df['converted']  # From customer features

# For modeling, use the sequence version
X_customer = customer_df.drop(columns=['numero_compte', 'converted'], errors='ignore')
X_customer_clean, y_customer_clean = prepare_features(X_customer, y_customer, "Customer Features")

X_sequence = sequence_df.drop(columns=['numero_compte', 'converted'], errors='ignore')
X_sequence_clean, y_sequence_clean = prepare_features(X_sequence, y_sequence, "Sequence Features")

new_df = create_timeline_interaction_features(new_df)
new_df, _ = create_catboost_interaction_features(new_df)
new_df, _ = create_efficiency_interaction_features(new_df)
new_df, _ = create_engagement_interaction_features(new_df)

new_df = create_advanced_interaction_features(new_df)
new_df = create_conversion_pattern_features(new_df)
new_df = create_precision_optimization_features(new_df)
new_df = create_price_dominant_features(new_df) 

new_df = create_price_binning_features(new_df)
new_df = create_simulation_discovery_features(new_df)

X_new = new_df.drop(columns=['numero_compte', 'converted'], errors='ignore')
X_new_clean, y_new_clean = prepare_features(X_new, y_new, "New Features")


print("\n" + "="*80)
print("TESTING FEATURE IMPROVEMENT")
print("="*80)

# Test 1: Customer features only (baseline)
print("\n🧪 TEST 1: ENHANCED CUSTOMER FEATURES (Baseline)")
result = train_catboost(X_customer_clean, y_customer_clean, 'improved_customer_model')
df = result['X_test']
df['converted'] = result['y_test']
model_evaluation_report(df, result['model'], result['features'], 'converted')

# Test 2: Sequence features (if available)
print("\n🧪 TEST 2: SEQUENCE FEATURES (Advanced)")
result = train_catboost(X_sequence_clean, y_sequence_clean, 'sequence_prediction_model')
df = result['X_test']
df['converted'] = result['y_test']
model_evaluation_report(df, result['model'], result['features'], 'converted')


# Test 3: New features 
print("\n🧪 TEST 3: NEW FEATURES (Advanced)")
result = train_catboost(X_new_clean, y_new_clean, 'new_prediction_model')
df = result['X_test']
df['converted'] = result['y_test']
model_evaluation_report(df, result['model'], result['features'], 'converted')
# Out:
# /home/valeriya/project/homeserve/credit_policy/.direnv/python-3.12.0/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.2) or chardet (7.2.0)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# 📊 Original quote data: 37,008 quotes from 25,716 customers
#
# ================================================================================
# STRATEGY: CREATE FEATURES
# ================================================================================
# Creating OPTIMIZED customer features (mode: first_conversion)...
#   Filtering post-first-purchase data...
#   Customers: 25,716, Quotes: 35,953
#   Calculating features...
#   Calculating price trajectory (optimized)...
# ✓ Created 14 leakage-free features
# → 25,716 customers | 39.4% converters
# ⏱️  Execution time: 11.1 seconds
# ⚠️  11.1s (target was 3s)
# ================================================================================
# CREATING SEQUENCE FEATURES (mode: first_conversion)
# ================================================================================
#   Total quotes: 37,008
#   Total customers: 25,716
#   Using product column: regroup_famille_equipement_produit_principal
#   Window days: 30
#   Filtering post-first-purchase data...
#     Customers after filter: 25,716
#     Quotes after filter: 36,003
# ⚡ Processing 25,716 customers with sequence features...
#   Processed 5,000/25,716 customers
#   Processed 10,000/25,716 customers
#   Processed 15,000/25,716 customers
#   Processed 20,000/25,716 customers
#   Processed 25,000/25,716 customers
#
#   Adding categorical features...
#
# ================================================================================
# ✅ SEQUENCE FEATURES CREATED
# ================================================================================
#   Total customers: 25,716
#   Converters: 10,139 (39.4%)
#   Features created: 21
#   Product column used: regroup_famille_equipement_produit_principal
#   Execution time: 10.8 seconds
# 25716
# ================================================================================
# CREATING BRAND FEATURES
# ================================================================================
# Processing 37,008 quotes for 25,716 customers
# 👥 Single groupby aggregation...
#   Processing 25,716 customers with brand data
# ⚡ Vectorized feature calculation...
# ✅ Vectorized calculations complete
# 📝 Creating final DataFrame...
#
# ✅ Created 8 brand features
#    Total customers: 25,716
#    With brand data: 25,716
#
# 📊 FEATURE SUMMARY:
# --------------------------------------------------
# brand_loyalty_index       : mean = 0.922
# brand_switches            : mean = 0.189
# brand_consistency         : mean = 0.838
# prefers_premium_brand     : mean = 0.240
# prefers_budget_brand      : mean = 0.326
# 25716
# ================================================================================
# CREATING ENHANCED MODEL FEATURES (HYPER-FAST)
# ================================================================================
# Processing 25,716 customers
# ⚡ Hyper-fast calculations...
# 📝 Creating final DataFrame...
#
# ✅ Created 15 model features
#    Customers: 25,716
#    NEW: model_name_complexity (std), efficiency_class_score
# 25716
# ================================================================================
# CREATING LEAKAGE-FREE MARKET FEATURES
# ================================================================================
# 🚨 FORCE REMOVING LEAKY BRANDS
# Found 25 leaky brands
# Found 25 near-perfect brands (≥99% or ≤1%)
# Total suspicious brands to remove: 25
#   - WATTS: 0.0% (3.0 quotes)
#   - AIRZONE: 0.0% (1.0 quotes)
#   - ASTRAL POOL: 0.0% (1.0 quotes)
#   - FROLING: 0.0% (3.0 quotes)
#   - BRUGMAN: 0.0% (1.0 quotes)
#   - THERMADOR: 100.0% (1.0 quotes)
#   - ABB: 0.0% (1.0 quotes)
#   - WEISHAUPT: 0.0% (1.0 quotes)
#   - SAMSUNG: 0.0% (2.0 quotes)
#   - KERMI: 0.0% (1.0 quotes)
# Replaced 41 quotes with 'SUSPICIOUS_BRAND'
# Remaining leaky brands after removal: 0
# Processing 37,008 quotes for 25,716 customers
# Using ALL quotes for market features (brand preferences are stable)
#   Quotes for feature calculation: 37,008
# 👥 Grouping customer data...
#   Processing 25,716 customers with brand data
# ⚡ Calculating leakage-free features...
# ✅ Calculations complete
# 🎯 Adding target variable...
#
# ✅ Created 7 leakage-free market features
#    Total customers: 25,716
#    With brand data: 25,716
#    Converters: 10,139 (39.4%)
#
# 🔍 Feature correlations with target (should be < 0.3 for no leakage):
#    ✅ premium_brand_ratio      : -0.032
#    ✅ budget_brand_ratio       : 0.022
#    ✅ brand_consistency        : -0.043
#    ✅ brand_diversity_index    : 0.042
# 25716
# ================================================================================
# CREATING EQUIPMENT UPGRADE PATH FEATURES (LEAKAGE-SAFE VERSION)
# ================================================================================
# 🔍 Applying first conversion filtering...
# ⚠️  No first_purchase_dates provided - using all data (RISKY!)
# Processing equipment upgrade data for 25,716 customers
# 🔍 Ensuring chronological order to prevent leakage...
# ✅ Data sorted chronologically by customer and date
#
# 📊 Applying complexity and seasonality mappings...
# Customers with equipment data: 25,716
#
# 🔧 Computing group-by aggregations...
# 🔄 Merging aggregated features...
# ⚡ Computing derived features...
# ❌ Removing leaking features: upgrade_trajectory_score, has_upgrade, has_downgrade
# 🧹 Cleaning up missing values...
#
# ✅ Created 20 SAFE equipment upgrade features
#    Samples: 25,716 customers
#    REMOVED: upgrade_trajectory_score, has_upgrade, has_downgrade (potential leakage)
#    FIRST CONVERSION MODE: DISABLED
#
# 📊 KEY UPGRADE FEATURES SUMMARY:
# ------------------------------------------------------------
# equipment_family_consistency        : mean=0.926, std=0.262, non-zero=92.6%
# equipment_maturity_level            : mean=0.321, std=0.111, non-zero=100.0%
# equipment_variety_index             : mean=0.074, std=0.262, non-zero=7.4%
# early_technology_adopter            : mean=0.197, std=0.398, non-zero=19.7%
# 25716
# ================================================================================
# CREATING SOLUTION COMPLEXITY FEATURES (VECTORIZED)
# ================================================================================
# 🔍 Applying first conversion filtering...
# ⚠️  No first_purchase_dates provided - using all data
# Processing solution complexity for 25,716 customers
# 🔍 Ensuring chronological order...
# ✅ Data sorted chronologically by customer and date
#
# 📊 Preparing data for vectorized processing...
# Processing 37,008 equipment records
# 🔧 Creating system type indicators...
# 📈 Computing aggregated features...
# ⚡ Calculating complexity scores...
# 🌱 Calculating energy efficiency...
# 🔗 Computing system integration...
# 🏆 Determining primary systems...
# 🔄 Merging all features...
# 📊 Calculating sophistication tiers...
#
# ✅ Created 27 solution complexity features
#    Samples: 25,716 customers
#    FIRST CONVERSION MODE: DISABLED
#
# 📊 SOLUTION COMPLEXITY FEATURES SUMMARY:
# ------------------------------------------------------------
# multi_system_count                  : mean=0.935, std=0.318
# solution_complexity_score           : mean=2.714, std=0.954
# has_complete_heating_solution       : mean=0.000, std=0.000
# energy_efficiency_score             : mean=0.794, std=1.850
# system_integration_level            : mean=0.018, std=0.126
# primary_system_dominance            : mean=0.967, std=0.121
# sophistication_score                : mean=0.971, std=0.763
# future_proofing_score               : mean=0.054, std=0.109
# 25716
# ================================================================================
# CREATING TIMELINE FEATURES (mode: first_conversion)
# ================================================================================
# Using date column: 'dt_creation_devis'
# Processing 25,716 customers
#
# 🔧 NO FILTERING: Using ALL quotes for timeline features
#    (Like market features, timeline patterns are stable characteristics)
#    Quotes for features: 37,008
#
# 📅 Creating month features (optimized, always 1-12)...
#
# 🎯 Adding target variable...
#
# 🚨 VERIFICATION: Data availability (should be ~100% for both)
#   Converters with data: 100.0%
#   Non-converters with data: 100.0%
#   Difference: 0.0% (should be < 10%)
#
# ✅ Created 20 timeline features
#    Total customers: 25,716
#    Converters: 10,139 (39.4%)
# ✅ VERIFIED: All 12 month features present: month_1_count through month_12_count
# 25716
# ================================================================================
# CREATING ADVANCED TIMELINE FEATURES (mode: first_conversion)
# ================================================================================
# Initial data: 37,008 quotes for 25,716 customers
#
# 🔧 NO FILTERING: Using ALL quotes for advanced timeline features
#    (Like basic timeline and market features)
#    Quotes for features: 37,008
#
# 🎯 Adding target variable...
#
# ✅ Created advanced timeline features for 25,716 customers
#    With data: 25,716
#    Converters: 10,139 (39.4%)
#
# 🚨 VERIFICATION: Data balance
#    Converters with data: 100.0%
#    Non-converters with data: 100.0%
#    Difference: 0.0%
# 25716
# 🔍 Applying first conversion filtering...
# ⚠️  No first_purchase_dates provided - using all data
# ⚡ Creating enhanced role features...
# ✅ Created 7 LEAKAGE-SAFE commercial features
#    New features: role_diversity, primary_role_type, role_stability, interaction_count
# 25716
# ================================================================================
# 🚀 ULTRA-FAST CUSTOMER-LEVEL PROCESS FEATURES
# ================================================================================
# Processing 37,008 quotes for 25,716 customers
# 👥 Vectorized aggregation...
# ⚡ Vectorized feature calculation...
#   → Creating derived features...
# 📝 Finalizing features...
#
# ✅ Created 11 process features for 25,716 customers
# ⏱️  Execution time: 4.91 seconds
#
# 📊 FEATURE SUMMARY:
# --------------------------------------------------
# Adoption Rate             : mean = 0.599, std = 0.484
# Ever Used (%)             : 61.1%
# Consistency               : mean = 0.974, std = 0.158
# Confidence Score          : mean = 0.824, std = 0.218
# 25716
# Creating features from raw data with error correction...
#   → Single groupby for all features...
#   → Vectorized calculations...
#   → Optimized decision speed features...
#   → Additional features...
#   → Final cleanup...
# ✅ Created 32 optimized features for 25716 customers
#    Columns: ['numero_compte', 'total_quotes', 'unique_agencies', 'unique_equipment', 'unique_brands', 'avg_price', 'max_price', 'min_price', 'new_process_count', 'unique_commercials', 'engagement_days', 'engagement_density', 'is_single_quote', 'new_process_ratio', 'process_consistency', 'price_range', 'price_volatility', 'primary_equipment', 'primary_brand', 'avg_days_between', 'std_days_between', 'min_days_between', 'max_days_between', 'is_quick_decider', 'optimal_timing_score', 'tire_kicker_indicator', 'engagement_consistency', 'is_senior_commercial', 'agency_switches', 'price_consistency_score', 'equipment_focus_score', 'brand_loyalty_score', 'converted']
#    Dtypes: [dtype('O') dtype('int64') dtype('float64')]
# 25716
#
# 🔧 ENCODING & PREPARING FOR MODELING...
#   Preparing Customer Features...
#   Features: 14, Samples: 25716
#
# 🔧 ENCODING & PREPARING FOR MODELING...
#   Preparing Sequence Features...
#   Features: 31, Samples: 25716
# ================================================================================
# 🔧 COMPLETE PHASE B FEATURE ENGINEERING
# ================================================================================
#
# 1️⃣ CATBOOST INTERACTION FEATURES
# ----------------------------------------
#
# 2️⃣ EFFICIENCY-FOCUSED FEATURES
# ----------------------------------------
#
# 3️⃣ INTENT CLARITY FEATURES (From Roadmap)
# ----------------------------------------
#
# 4️⃣ BUDGET CERTAINTY FEATURES
# ----------------------------------------
#
# ✅ PHASE B COMPLETE
#    Total new features created: 13
#    Total features in dataset: 191
#
# 📋 FEATURE CATEGORIES:
#   • CatBoost Interactions: 4 features
#     - engagement_product_interaction
#     - historical_price_interaction
#     - quote_consistency_score
#     ... and 1 more
#   • Efficiency Focus: 5 features
#     - decision_efficiency_score
#     - is_short_cycle
#     - engagement_velocity
#     ... and 2 more
#   • Intent Clarity: 3 features
#     - equipment_consistency_score
#     - price_discovery_range
#     - price_consistency
#   • Budget Certainty: 1 features
#     - price_discovery_efficiency
#
# ============================================================
# 🎯 EFFICIENCY-FOCUSED FEATURE ENGINEERING
# ============================================================
#
# ✅ Created 15 efficiency-focused features:
#   • decision_efficiency_score: quotes / days (efficiency)
#   • is_short_cycle: avg_days < 7 (short cycle)
#   • engagement_intensity: quotes × (1/days)
#   • is_very_short_cycle: avg_days < 3 (very short)
#   • solution_focus_score: 1/(variety × complexity)
#   • is_focused_shopper: low variety & complexity
#   • is_simple_solution: single equipment & simple
#   • price_discovery_efficiency: 1/(range × quotes)
#   • budget_certainty: 1 - range/max_price
#   • brand_efficiency: brand_loyalty_index
#   • brand_decision_efficiency: loyalty × (1 - switch_rate)
#   • learning_efficiency: current_quotes / historical_quotes
#   • is_experienced_shopper: has historical quotes
#   • equipment_consistency_score: 1/(equipment_variety + 1)
#   • price_discovery_range: max_price - min_price
#
# 📊 FEATURE STATISTICS (first 5 new features):
#   • decision_efficiency_score: mean=1.056, std=0.569
#   • is_short_cycle: mean=0.889, std=0.314
#   • engagement_intensity: mean=1.056, std=0.569
#   • is_very_short_cycle: mean=0.867, std=0.340
#   • solution_focus_score: mean=0.311, std=0.214
#
# 📈 Total features in dataset: 199
# 🎯 New efficiency features: 15
#
# ============================================================
# 🎯 EFFICIENCY-FOCUSED FEATURE ENGINEERING
# ============================================================
#
# 📈 ADDING YOUR SUGGESTED FEATURES:
#   ✓ engagement_speed_score
#   ✓ engagement_consistency
#   ✓ decision_complexity
#   ✓ brand_consistency
#
# ================================================================================
# 🚀 CREATING ADVANCED INTERACTION FEATURES (Error Analysis Based)
# ================================================================================
#
# ✅ Created 21 new interaction features
# 📊 NEW FEATURES ADDED:
#    1. aggressive_discount_shopper
#    2. complexity_per_quote
#    3. decision_quality
#    4. discount_aggressiveness
#    5. discount_relative_to_price
#    6. engagement_consistency_score
#    7. engagement_velocity_scaled
#    8. equipment_focus_ratio
#    9. error_driver_composite
#   10. high_price_sensitivity
#   11. high_quality_decision
#   12. high_value_potential
#   13. loyalty_per_quote
#   14. pattern_variability
#   15. price_position
#   16. price_sensitivity
#   17. price_stability
#   18. quick_but_inconsistent
#   19. quick_high_value
#   20. shopping_behavior
#   21. speed_complexity_ratio
#
# 📈 KEY NEW FEATURES STATISTICS:
#                             mean       std        min       max
# engagement_velocity       1.0564    0.5692     0.0019    6.0000
# price_stability           0.9082    0.1930     0.0206    1.0000
# discount_aggressiveness -36.2270  204.4301 -5360.0247   -0.0000
# decision_quality          5.9845   21.6561     0.1996  598.6280
# shopping_behavior         0.0000    0.0000     0.0000    0.0000
# price_sensitivity         0.1272    0.3032     0.0000    5.2997
# error_driver_composite    0.0090    1.5912  -151.7082   42.4236
# pattern_variability       0.0648    0.2963     0.0000   12.1200
#
# ================================================================================
#
# ================================================================================
# 🎯 CREATING CONVERSION PATTERN FEATURES (Based on Error Analysis)
# ================================================================================
#
# ✅ Created 11 conversion pattern features
#
# 📊 KEY CONVERSION PATTERNS DISCOVERED:
#   • Perfect consistency (1.000) → SUSPICIOUS (false positive pattern)
#   • Lower engagement density → BETTER (converter pattern)
#   • High brand loyalty + perfect consistency → FALSE POSITIVE risk
#   • High consistency + low density → CONVERTER pattern
#
# ================================================================================
# 🎯 CREATING PRECISION OPTIMIZATION FEATURES
# ================================================================================
#
# ✅ Created 9 precision optimization features
#
# 📊 FOCUS: Reducing False Positives
#   • FP Risk Score: Identifies high-consistency + high-density cases
#   • Too Perfect Consistency: Flags suspicious 1.000 scores
#   • Converter vs FP Ratio: Balances both patterns
#
# ================================================================================
# 💰 CREATING PRICE-DOMINANT FEATURES
# ================================================================================
#
# ✅ Created 15 price-dominant features
#
# 📊 LEVERAGING YOUR STRONGEST SIGNAL:
#   • max_price is your #1 predictor (importance 200)
#   • avg_current_price is #2 (importance 196)
#   • New features combine price with other top signals
#
# ================================================================================
# 📊 CREATING PRICE BINNING FEATURES (Sweet Spot Detection)
# ================================================================================
#
# Binning 6 price features...
#
# ✅ Created 51 price binning features
#
# 📊 BINNING TYPES CREATED:
#   • Quantile bins (equal frequency)
#   • Business tier bins (Very Low to Very High)
#   • Sweet spot indicators (detected from conversion rates)
#   • One-hot encoded dummies
#   • Interactions with consistency
#
# 🎯 SWEET SPOT DETECTION ACTIVE - Finding optimal price ranges
# ================================================================================
# CREATING SIMULATION-DISCOVERY FEATURES
# ================================================================================
# ⚠️ Missing columns (will skip dependent features): ['has_heat_pump', 'has_stove', 'has_boiler', 'has_ac', 'customer_quote_count']
# ✅ Created 'follow_up_opportunity' from existing 'is_single_quote'
#
# ✅ Added 308 simulation-discovery features
#
# 🔧 ENCODING & PREPARING FOR MODELING...
#   Preparing New Features...
#   Features: 308, Samples: 25716
#
# ================================================================================
# TESTING FEATURE IMPROVEMENT
# ================================================================================
#
# 🧪 TEST 1: ENHANCED CUSTOMER FEATURES (Baseline)
# ✓ CatBoost Model saved: improved_customer_model.pkl
# ✓ AUC: 0.631
# ✓ F1 Score: 0.515
# ✓ Training samples: 20572
# ✓ Test samples: 5144
# ================================================================================
# COMPLETE MODEL VALIDATION PACKAGE
# ================================================================================
#
# 📊 STEP 1: DISCRIMINATION POWER
# ----------------------------------------
# • ROC-AUC: 0.6314
# • PR-AUC: 0.5362
# • KS Statistic: 0.185 (WEAK discrimination)
# • Optimal Threshold: 0.509
#
# 💼 STEP 2: BUSINESS IMPACT
# ----------------------------------------
# Verification of decile assignment:
# Decile 1 mean prob: 0.727
# Decile 10 mean prob: 0.277
# • Top Decile Lift: 0.56x
# • Top 30% captures: 40.5% of positives
# • Baseline response rate: 39.4%
# • Top decile response: 64.9%
#
# 📈 STEP 4: CONFUSION MATRIX
# ----------------------------------------
# At threshold 0.509:
# • Accuracy: 0.611
# • Precision: 0.507
# • Recall: 0.505
# • F1-Score: 0.506
# • True Positives: 1025
# • False Positives: 997
# • True Negatives: 2119
# • False Negatives: 1003
#
# ================================================================================
# FINAL VALIDATION SUMMARY
# ================================================================================
#
# ✅ DISCRIMINATION POWER:
#    KS Statistic: 0.185 (WEAK discrimination)
#
# ✅ BUSINESS VALUE:
#    Efficiency: 0.56x better than random
#    Coverage: Top 30% → 40.5% captured
#
# ✅ MODEL QUALITY:
#    ROC-AUC: 0.6314 (Excellent if >0.8)
#    PR-AUC: 0.5362 (Excellent if >0.7)
#
# ✅ OPERATIONAL METRICS:
#    Optimal Threshold: 0.509
#    Precision at threshold: 0.507
#    Recall at threshold: 0.505
#
# 🧪 TEST 2: SEQUENCE FEATURES (Advanced)
# ✓ CatBoost Model saved: sequence_prediction_model.pkl
# ✓ AUC: 0.696
# ✓ F1 Score: 0.554
# ✓ Training samples: 20572
# ✓ Test samples: 5144
# ================================================================================
# COMPLETE MODEL VALIDATION PACKAGE
# ================================================================================
#
# 📊 STEP 1: DISCRIMINATION POWER
# ----------------------------------------
# • ROC-AUC: 0.6965
# • PR-AUC: 0.6467
# • KS Statistic: 0.267 (WEAK discrimination)
# • Optimal Threshold: 0.517
#
# 💼 STEP 2: BUSINESS IMPACT
# ----------------------------------------
# Verification of decile assignment:
# Decile 1 mean prob: 0.835
# Decile 10 mean prob: 0.211
# • Top Decile Lift: 0.36x
# • Top 30% captures: 45.5% of positives
# • Baseline response rate: 39.4%
# • Top decile response: 84.3%
#
# 📈 STEP 4: CONFUSION MATRIX
# ----------------------------------------
# At threshold 0.517:
# • Accuracy: 0.658
# • Precision: 0.573
# • Recall: 0.519
# • F1-Score: 0.544
# • True Positives: 1052
# • False Positives: 785
# • True Negatives: 2331
# • False Negatives: 976
#
# ================================================================================
# FINAL VALIDATION SUMMARY
# ================================================================================
#
# ✅ DISCRIMINATION POWER:
#    KS Statistic: 0.267 (WEAK discrimination)
#
# ✅ BUSINESS VALUE:
#    Efficiency: 0.36x better than random
#    Coverage: Top 30% → 45.5% captured
#
# ✅ MODEL QUALITY:
#    ROC-AUC: 0.6965 (Excellent if >0.8)
#    PR-AUC: 0.6467 (Excellent if >0.7)
#
# ✅ OPERATIONAL METRICS:
#    Optimal Threshold: 0.517
#    Precision at threshold: 0.573
#    Recall at threshold: 0.519
#
# 🧪 TEST 3: NEW FEATURES (Advanced)
# ✓ CatBoost Model saved: new_prediction_model.pkl
# ✓ AUC: 0.760
# ✓ F1 Score: 0.617
# ✓ Training samples: 20572
# ✓ Test samples: 5144
# ================================================================================
# COMPLETE MODEL VALIDATION PACKAGE
# ================================================================================
#
# 📊 STEP 1: DISCRIMINATION POWER
# ----------------------------------------
# • ROC-AUC: 0.7598
# • PR-AUC: 0.7197
# • KS Statistic: 0.372 (MODERATE discrimination)
# • Optimal Threshold: 0.489
#
# 💼 STEP 2: BUSINESS IMPACT
# ----------------------------------------
# Verification of decile assignment:
# Decile 1 mean prob: 0.936
# Decile 10 mean prob: 0.169
# • Top Decile Lift: 0.21x
# • Top 30% captures: 51.3% of positives
# • Baseline response rate: 39.4%
# • Top decile response: 95.0%
#
# 📈 STEP 4: CONFUSION MATRIX
# ----------------------------------------
# At threshold 0.489:
# • Accuracy: 0.692
# • Precision: 0.601
# • Recall: 0.655
# • F1-Score: 0.627
# • True Positives: 1328
# • False Positives: 882
# • True Negatives: 2234
# • False Negatives: 700
#
# ================================================================================
# FINAL VALIDATION SUMMARY
# ================================================================================
#
# ✅ DISCRIMINATION POWER:
#    KS Statistic: 0.372 (MODERATE discrimination)
#
# ✅ BUSINESS VALUE:
#    Efficiency: 0.21x better than random
#    Coverage: Top 30% → 51.3% captured
#
# ✅ MODEL QUALITY:
#    ROC-AUC: 0.7598 (Excellent if >0.8)
#    PR-AUC: 0.7197 (Excellent if >0.7)
#
# ✅ OPERATIONAL METRICS:
#    Optimal Threshold: 0.489
#    Precision at threshold: 0.601
#    Recall at threshold: 0.655
# {'y_true': array([0., 0., 1., ..., 0., 0., 1.], shape=(5144,)),
#  'y_pred_proba': array([0.35789782, 0.13331534, 0.54630729, ..., 0.31024182, 0.69677883,
#         0.51214398], shape=(5144,)),
#  'y_pred': array([0, 0, 1, ..., 0, 1, 1], shape=(5144,)),
#  'roc_auc': 0.759770861975982,
#  'pr_auc': 0.7196538603672865,
#  'ks_statistic': np.float64(0.3717771481669971),
#  'optimal_threshold': np.float64(0.48859240363057305),
#  'top_decile_lift': np.float64(0.20685930947320044),
#  'decile_stats':    decile  count  positives  mean_prob  response_rate      lift  \
#  0       1    515      489.0   0.936263       0.949515  2.408433
#  1       2    514      299.0   0.662765       0.581712  1.475506
#  2       3    514      252.0   0.574291       0.490272  1.243571
#  3       4    515      220.0   0.522576       0.427184  1.083549
#  4       5    514      194.0   0.479376       0.377432  0.957352
#  5       6    514      157.0   0.436488       0.305447  0.774764
#  6       7    515      148.0   0.392649       0.287379  0.728933
#  7       8    514      129.0   0.341570       0.250973  0.636590
#  8       9    514       98.0   0.278327       0.190661  0.483611
#  9      10    515       42.0   0.169165       0.081553  0.206859
#
#     cum_population  cum_positives  cum_positives_pct
#  0       10.011664          489.0          24.112426
#  1       20.003888          788.0          38.856016
#  2       29.996112         1040.0          51.282051
#  3       40.007776         1260.0          62.130178
#  4       50.000000         1454.0          71.696252
#  5       59.992224         1611.0          79.437870
#  6       70.003888         1759.0          86.735700
#  7       79.996112         1888.0          93.096647
#  8       89.988336         1986.0          97.928994
#  9      100.000000         2028.0         100.000000  ,
#  'confusion_matrix': array([[2234,  882],
#         [ 700, 1328]]),
#  'metrics': {'accuracy': np.float64(0.692457231726283),
#   'precision': np.float64(0.6009049773755656),
#   'recall': np.float64(0.6548323471400395),
#   'f1': np.float64(0.6267107126002832)}}

# %%
X_test = result['X_test'].copy()  # Make a copy to avoid modifying the original
y_test = result['y_test']
model = result['model']

# Ensure X_test doesn't have the target column
if 'converted' in X_test.columns:
    X_test = X_test.drop(columns=['converted'])

y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, 'predict_proba') else None

# Create a dataframe for error analysis that includes the predictions
error_df = X_test.copy()
error_df['converted'] = y_test
error_df['predicted'] = y_pred
if y_pred_proba is not None:
    error_df['prediction_probability'] = y_pred_proba

error_results = comprehensive_error_analysis(
    X_test=X_test,
    y_test=y_test,
    y_pred=y_pred,
    y_pred_proba=y_pred_proba,
    original_df=error_df,  # Use the properly prepared dataframe
    customer_id_col='numero_compte'
)

analyze_feature_contribution_to_errors(model, X_test, y_test, y_pred)
create_error_visualization(error_results, y_test, y_pred, y_pred_proba)
# Out:
# ================================================================================
# COMPREHENSIVE ERROR ANALYSIS
# ================================================================================
#
# 📊 1. BASIC ERROR METRICS
# ------------------------------------------------------------
# Confusion Matrix:
#   True Negatives:    2318 (Correctly rejected)
#   False Positives:    798 (Predicted YES, actual NO) ← WASTED EFFORT
#   False Negatives:    766 (Predicted NO, actual YES) ← MISSED OPPORTUNITIES
#   True Positives:    1262 (Correctly predicted)
#
# Error Analysis:
#   • Total errors: 1,564 (30.4% of predictions)
#   • False Positive rate: 15.5% (wasted sales effort)
#   • False Negative rate: 14.9% (missed conversions)
#
# 📈 2. PREDICTION CONFIDENCE ANALYSIS
# ------------------------------------------------------------
# Accuracy by Confidence Level:
#   • Very Low   confidence: 86.6% accurate (920 predictions)
#   • Low        confidence: 75.5% accurate (951 predictions)
#   • Medium     confidence: 57.1% accurate (2,182 predictions)
#   • High       confidence: 55.1% accurate (494 predictions)
#   • Very High  confidence: 91.6% accurate (597 predictions)
#
# ⚠️  Low Confidence Predictions (40-60%):
#   • Count: 2,182 (42.4% of predictions)
#   • These need human review or better features
#
# 🔍 3. FEATURE ANALYSIS OF ERRORS
# ------------------------------------------------------------
# Feature Value Differences by Error Type (mean values):
#             total_quotes  avg_days_between_quotes  engagement_density  solution_complexity_score  equipment_variety_count  brand_loyalty_index
# error_type
# FN                 1.282                    3.692               1.102                      2.700                    1.054                0.944
# FP                 1.236                   17.881               0.868                      2.722                    1.008                0.976
# TN                 1.434                    3.509               1.200                      2.693                    1.091                0.907
# TP                 1.710                   29.704               0.880                      2.782                    1.134                0.888
#
# 📊 Key Feature Differences:
#   • total_quotes                  : FP are -0.474 vs TP
#   • total_quotes                  : FN are -0.428 vs TP
#   • avg_days_between_quotes       : FP are -11.823 vs TP
#   • avg_days_between_quotes       : FN are -26.012 vs TP
#   • engagement_density            : FP are -0.012 vs TP
#   • engagement_density            : FN are +0.222 vs TP
#   • solution_complexity_score     : FP are -0.061 vs TP
#   • solution_complexity_score     : FN are -0.082 vs TP
#   • equipment_variety_count       : FP are -0.126 vs TP
#   • equipment_variety_count       : FN are -0.080 vs TP
#
# 🎯 4. ERROR ANALYSIS BY ENGAGEMENT LEVEL
# ------------------------------------------------------------
#
# 💡 5. FALSE NEGATIVE ANALYSIS (MISSED OPPORTUNITIES)
# ------------------------------------------------------------
#
# 🎯 6. ACTIONABLE RECOMMENDATIONS
# ============================================================
#  1. Model is TOO AGGRESSIVE (too many False Positives)
#  2. → Increase prediction threshold
#  3. → Add features to identify 'tire-kickers'
#  4. Too many uncertain predictions (42.4%)
#  5. → Need better features for edge cases
#  6. → Consider human review for 40-60% confidence range
#
# 🔬 FEATURE CONTRIBUTION TO ERRORS
# ------------------------------------------------------------
# Top 10 Most Important Features:
#                                        feature  importance
# consistency_x_advanced_timeline_data_available   23.717767
#          consistency_x_timeline_data_available   18.805505
#                            learning_efficiency   12.008602
#                        quote_consistency_score    7.449409
#                               consistency_tier    4.187166
#              consistency_distance_from_perfect    2.985140
#                                    value_score    1.313533
#                                     nom_agence    1.306644
#                     discount_relative_to_price    1.075524
#                                    main_agency    0.823433
#
# SHAP Analysis for Errors:
# Features with largest SHAP impact on errors:
#   • consistency_x_advanced_timeline_data_available
#   • consistency_x_timeline_data_available
#   • nom_agence
#   • discount_relative_to_price
#   • value_score

# %%
from ml_training.catboost_interactions import analyze_catboost_interactions

# Assuming you have your trained CatBoost model
cat_model = result['model']  # From your CatBoost results
X_features = result['features']  # Feature names
X_test_sample = result['X_test'].iloc[:100]  # Sample for analysis
X_test_sample = X_test_sample.drop(columns=['converted'])

# Run comprehensive interaction analysis
print("📈 CATBOOST INTERACTION ANALYSIS REPORT")
print("=" * 60)

# 1. Basic interaction analysis
analyze_catboost_interactions(cat_model, X_features, X_test_sample)
# Out:
# 📈 CATBOOST INTERACTION ANALYSIS REPORT
# ============================================================
# 🔬 CATBOOST FEATURE INTERACTION ANALYSIS
# ============================================================
# ⚠️ Could not extract direct interactions: Invalid data type=<class 'pandas.core.frame.DataFrame'>, must be catboost.Pool.
#
# 🎯 SHAP-Based Interaction Analysis:
# --------------------------------------------------
#
# 🔍 Top Feature Interactions (SHAP-based):
#
#   • Interactions with 'discount_relative_to_price':
#     - discount_relative_to_price × avg_discount_pct: 0.965
#     - discount_relative_to_price × main_agency: 0.351
#
#   • Interactions with 'nom_agence':
#     - nom_agence × main_agency: 0.974
#     - nom_agence × avg_discount_pct: 0.327
#     - nom_agence × standard_model_ratio: 0.222
#
#   • Interactions with 'learning_efficiency':
#     - learning_efficiency × avg_discount_pct: 0.243
#     - learning_efficiency × price_trajectory: 0.230
#     - learning_efficiency × std_days_between_quotes: 0.193
#
#   • Interactions with 'consistency_x_timeline_data_available':
#     - consistency_x_timeline_data_available × price_trajectory: 0.236
#     - consistency_x_timeline_data_available × avg_discount_pct: 0.231
#     - consistency_x_timeline_data_available × std_days_between_quotes: 0.152
#
#   • Interactions with 'consistency_x_advanced_timeline_data_available':
#     - consistency_x_advanced_timeline_data_available × std_days_between_quotes: 0.260
#     - consistency_x_advanced_timeline_data_available × avg_discount_pct: 0.217
#     - consistency_x_advanced_timeline_data_available × price_trajectory: 0.203
#
# 💡 Suggested Interaction Features (Based on Analysis):
# --------------------------------------------------
#   • engagement_velocity = f(total_quotes, avg_days_between_quotes)
#   • price_consistency = f(min_price, max_price)
#   • engagement_complexity = f(engagement_density, solution_complexity_score)
#   • decision_diversity = f(equipment_variety_count, brand_loyalty_index)
#   • discount_strategy = f(avg_discount_pct, price_range)
